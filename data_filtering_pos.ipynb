# %%
import os
import re
import pycountry
import pandas as pd

import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/lingyaol/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/lingyaol/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
filters = ['parking']
filters_pos = ['park', 'parked']

def check_filters(text):
    text = text.lower().strip()
    if any(f in text for f in filters):
        return True
    elif any(f in text.split() for f in filters_pos):
        tokens = word_tokenize(text)
        pos_tags = pos_tag(tokens)
        for word, pos in pos_tags:
            if (pos == 'VB' or pos == 'VBD' or pos == 'VBG' or pos == 'VBN' or pos == 'VBP' or pos == 'VBZ') and (word in filters_pos):
                return True
        return False
    else:
        return False


def filter_data(filename1, filename2):
    # read dataframe 1 and 2
    # process dataframe 2 in chunks
    chunksize = 10000
    filtered_df2_chunks = []
    for chunk in pd.read_json(filename2, compression='gzip', orient='records', lines=True, chunksize=chunksize):
        chunk['text'] = chunk['text'].astype(str)
        chunk = chunk.dropna(subset='text')
        filtered_chunk = chunk[chunk['text'].apply(check_filters)]
        filtered_df2_chunks.append(filtered_chunk)
    filtered_df2 = pd.concat(filtered_df2_chunks)
    print(f"Filter file {filename2} ----- after: {len(filtered_df2)}")
    filtered_df2['gmap_id'] = filtered_df2['gmap_id'].astype(str)
    gmap_list = list(set(filtered_df2['gmap_id'].tolist()))
    # filter dataframe 1
    df1 = pd.read_json(filename1, compression='gzip', orient='records', lines=True)
    df1['gmap_id'] = df1['gmap_id'].astype(str)
    filtered_df1 = df1[df1['gmap_id'].isin(gmap_list)]
    print(f"Filter file {filename1} ----- before: {len(df1)} after: {len(filtered_df1)}")    
    return filtered_df1, filtered_df2
    
    
def write_data(filtered_df1, filename1, filtered_df2, filename2):
    write_filename1 = filename1.replace('meta', 'filtered_meta').split('.json')[0] + '.csv'
    write_filename1 = os.path.join(save_meta_folder, write_filename1)
    write_filename2 = filename2.replace('review', 'filtered_review').split('.json')[0] + '.csv'
    write_filename2 = os.path.join(save_review_folder, write_filename2)
    filtered_df1.to_csv(write_filename1, index=False)
    print(f"Finish writing file: {write_filename1}")
    filtered_df2.to_csv(write_filename2, index=False)
    print(f"Finish writing file: {write_filename2}\n")

# %%
countries = pycountry.countries
excluded_states = []  # Add the states you want to exclude here
us_states = [state.name.replace(" ", "_") if " " in state.name else state.name for state in pycountry.subdivisions.get(country_code='US') if state.name not in excluded_states]
us_states = sorted(us_states)[:25]
print(us_states)

read_folder = "data-google-map"
filenames = os.listdir(read_folder)

save_meta_folder = 'parking-pos-meta'
if not os.path.exists(save_meta_folder):
    os.makedirs(save_meta_folder)

save_review_folder = 'parking-pos-review'
if not os.path.exists(save_review_folder):
    os.makedirs(save_review_folder)

meta_files = sorted([filename for filename in filenames if filename.lower().startswith('meta')])
review_files = sorted([filename for filename in filenames if filename.lower().startswith('review')])

for state in us_states:
    for (filename1, filename2) in zip(meta_files, review_files):
        if (state.lower() in filename1.lower()) and (state.lower() in filename2.lower()):
            read_filename1 = os.path.join(read_folder, filename1)
            read_filename2 = os.path.join(read_folder, filename2)
            filtered_df1, filtered_df2 = filter_data(read_filename1, read_filename2)
            write_data(filtered_df1, filename1, filtered_df2, filename2)
# Out:
# ['Alabama', 'Alaska', 'American_Samoa', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District_of_Columbia', 'Florida', 'Georgia', 'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan']
# Filter file data-google-map/review-Alabama.json.gz ----- after: 48765
# Filter file data-google-map/meta-Alabama.json.gz ----- before: 74967 after: 14637
# Finish writing file: parking-pos-meta/filtered_meta-Alabama.csv
# Finish writing file: parking-pos-review/filtered_review-Alabama.csv
#
# Filter file data-google-map/review-Alaska.json.gz ----- after: 6468
# Filter file data-google-map/meta-Alaska.json.gz ----- before: 12774 after: 2320
# Finish writing file: parking-pos-meta/filtered_meta-Alaska.csv
# Finish writing file: parking-pos-review/filtered_review-Alaska.csv
#
# Filter file data-google-map/review-Arizona.json.gz ----- after: 133347
# Filter file data-google-map/meta-Arizona.json.gz ----- before: 108579 after: 27729
# Finish writing file: parking-pos-meta/filtered_meta-Arizona.csv
# Finish writing file: parking-pos-review/filtered_review-Arizona.csv
#
# Filter file data-google-map/review-Arkansas.json.gz ----- after: 29188
# Filter file data-google-map/meta-Arkansas.json.gz ----- before: 47246 after: 8775
# Finish writing file: parking-pos-meta/filtered_meta-Arkansas.csv
# Finish writing file: parking-pos-review/filtered_review-Arkansas.csv
#
# Filter file data-google-map/review-California.json.gz ----- after: 869380
# Filter file data-google-map/meta-California.json.gz ----- before: 515961 after: 155520
# Finish writing file: parking-pos-meta/filtered_meta-California.csv
# Finish writing file: parking-pos-review/filtered_review-California.csv
#
# Filter file data-google-map/review-Colorado.json.gz ----- after: 136258
# Filter file data-google-map/meta-Colorado.json.gz ----- before: 106829 after: 28619
# Finish writing file: parking-pos-meta/filtered_meta-Colorado.csv
# Finish writing file: parking-pos-review/filtered_review-Colorado.csv
#
# Filter file data-google-map/review-Connecticut.json.gz ----- after: 43678
# Filter file data-google-map/meta-Connecticut.json.gz ----- before: 49200 after: 12646
# Finish writing file: parking-pos-meta/filtered_meta-Connecticut.csv
# Finish writing file: parking-pos-review/filtered_review-Connecticut.csv
#
# Filter file data-google-map/review-Delaware.json.gz ----- after: 14257
# Filter file data-google-map/meta-Delaware.json.gz ----- before: 14706 after: 3591
# Finish writing file: parking-pos-meta/filtered_meta-Delaware.csv
# Finish writing file: parking-pos-review/filtered_review-Delaware.csv
#
# Filter file data-google-map/review-District_of_Columbia.json.gz ----- after: 19964
# Filter file data-google-map/meta-District_of_Columbia.json.gz ----- before: 11060 after: 3385
# Finish writing file: parking-pos-meta/filtered_meta-District_of_Columbia.csv
# Finish writing file: parking-pos-review/filtered_review-District_of_Columbia.csv
#
# Filter file data-google-map/review-Florida.json.gz ----- after: 526198
# Filter file data-google-map/meta-Florida.json.gz ----- before: 378020 after: 94767
# Finish writing file: parking-pos-meta/filtered_meta-Florida.csv
# Finish writing file: parking-pos-review/filtered_review-Florida.csv
#
# Filter file data-google-map/review-Georgia.json.gz ----- after: 185169
# Filter file data-google-map/meta-Georgia.json.gz ----- before: 166381 after: 39154
# Finish writing file: parking-pos-meta/filtered_meta-Georgia.csv
# Finish writing file: parking-pos-review/filtered_review-Georgia.csv
#
# Filter file data-google-map/review-Hawaii.json.gz ----- after: 62876
# Filter file data-google-map/meta-Hawaii.json.gz ----- before: 21507 after: 8259
# Finish writing file: parking-pos-meta/filtered_meta-Hawaii.csv
# Finish writing file: parking-pos-review/filtered_review-Hawaii.csv
#
# Filter file data-google-map/review-Idaho.json.gz ----- after: 22962
# Filter file data-google-map/meta-Idaho.json.gz ----- before: 33214 after: 6770
# Finish writing file: parking-pos-meta/filtered_meta-Idaho.csv
# Finish writing file: parking-pos-review/filtered_review-Idaho.csv
#
# Filter file data-google-map/review-Illinois.json.gz ----- after: 166195
# Filter file data-google-map/meta-Illinois.json.gz ----- before: 179205 after: 42182
# Finish writing file: parking-pos-meta/filtered_meta-Illinois.csv
# Finish writing file: parking-pos-review/filtered_review-Illinois.csv
#
# Filter file data-google-map/review-Indiana.json.gz ----- after: 69884
# Filter file data-google-map/meta-Indiana.json.gz ----- before: 100391 after: 20413
# Finish writing file: parking-pos-meta/filtered_meta-Indiana.csv
# Finish writing file: parking-pos-review/filtered_review-Indiana.csv
#
# Filter file data-google-map/review-Iowa.json.gz ----- after: 26775
# Filter file data-google-map/meta-Iowa.json.gz ----- before: 47794 after: 8495
# Finish writing file: parking-pos-meta/filtered_meta-Iowa.csv
# Finish writing file: parking-pos-review/filtered_review-Iowa.csv
#
# Filter file data-google-map/review-Arkansas.json.gz ----- after: 29188
# Filter file data-google-map/meta-Arkansas.json.gz ----- before: 47246 after: 8775
# Finish writing file: parking-pos-meta/filtered_meta-Arkansas.csv
# Finish writing file: parking-pos-review/filtered_review-Arkansas.csv
#
# Filter file data-google-map/review-Kansas.json.gz ----- after: 28986
# Filter file data-google-map/meta-Kansas.json.gz ----- before: 46286 after: 8886
# Finish writing file: parking-pos-meta/filtered_meta-Kansas.csv
# Finish writing file: parking-pos-review/filtered_review-Kansas.csv
#
# Filter file data-google-map/review-Kentucky.json.gz ----- after: 46426
# Filter file data-google-map/meta-Kentucky.json.gz ----- before: 63193 after: 12902
# Finish writing file: parking-pos-meta/filtered_meta-Kentucky.csv
# Finish writing file: parking-pos-review/filtered_review-Kentucky.csv
#
# Filter file data-google-map/review-Louisiana.json.gz ----- after: 45554
# Filter file data-google-map/meta-Louisiana.json.gz ----- before: 63315 after: 12090
# Finish writing file: parking-pos-meta/filtered_meta-Louisiana.csv
# Finish writing file: parking-pos-review/filtered_review-Louisiana.csv
#
# Filter file data-google-map/review-Maine.json.gz ----- after: 19053
# Filter file data-google-map/meta-Maine.json.gz ----- before: 24853 after: 5623
# Finish writing file: parking-pos-meta/filtered_meta-Maine.csv
# Finish writing file: parking-pos-review/filtered_review-Maine.csv
#
# Filter file data-google-map/review-Maryland.json.gz ----- after: 107931
# Filter file data-google-map/meta-Maryland.json.gz ----- before: 78144 after: 22279
# Finish writing file: parking-pos-meta/filtered_meta-Maryland.csv
# Finish writing file: parking-pos-review/filtered_review-Maryland.csv
#
# Filter file data-google-map/review-Massachusetts.json.gz ----- after: 100736
# Filter file data-google-map/meta-Massachusetts.json.gz ----- before: 92520 after: 25099
# Finish writing file: parking-pos-meta/filtered_meta-Massachusetts.csv
# Finish writing file: parking-pos-review/filtered_review-Massachusetts.csv
#
# Filter file data-google-map/review-Michigan.json.gz ----- after: 116922
# Filter file data-google-map/meta-Michigan.json.gz ----- before: 158819 after: 34291
# Finish writing file: parking-pos-meta/filtered_meta-Michigan.csv
# Finish writing file: parking-pos-review/filtered_review-Michigan.csv
